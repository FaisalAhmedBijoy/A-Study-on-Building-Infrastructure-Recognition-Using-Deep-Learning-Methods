# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import PIL
import glob

# %%
print('Current working directory: ',os.getcwd())
# Out:
# Current working directory:  C:\Users\Shimul\Documents\Building CSE 4000 Thesis

# %% [markdown]
# ## Dataset path location using glob

# %%
building_house=glob.glob('dataset_building/building_house/*.*')
mosque=glob.glob('dataset_building/mosque/*.*')
temple=glob.glob('dataset_building/temple/*.*')
tinshed=glob.glob('dataset_building/tinshed/*.*')
sky_building=glob.glob('dataset_building/sky_building/*.*')
mud_house=glob.glob('dataset_building/mud_house/*.*')

# %%
print('Building house data : ',len(building_house))
print('Mosque data: ',len(mosque))
print('Temple data: ',len(temple))
print('Tinshed data: ',len(tinshed))
print('Sky building data: ',len(sky_building))
print('Mud house data: ',len(mud_house))
# Out:
# Building house data :  250
# Mosque data:  250
# Temple data:  250
# Tinshed data:  250
# Sky building data:  250
# Mud house data:  250

# %%
dataset_classes=[building_house,mosque,temple,tinshed,sky_building,mud_house]
total_class=len(dataset_classes)
print('Total dataset class: ',total_class)
# Out:
# Total dataset class:  6

# %% [markdown]
# ## Dataset Preprocessing using ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
WIDTH=224
HEIGHT=224

# %%
train_generator = ImageDataGenerator(rescale=1./255,
                                    horizontal_flip=True,
                                    shear_range=0.1 ,
                                    zoom_range=0.1,
                                    #rotation_range=30,
                                    height_shift_range=0.1,
                                    fill_mode='nearest')
                                     
validation_generator=ImageDataGenerator(rescale=1./255)

train_dataset = train_generator.flow_from_directory(batch_size=32,
                                                 directory='dataset_building/train',
                                                 shuffle=True,
                                                 target_size=(WIDTH, HEIGHT),
                                                 class_mode='categorical')

validation_dataset = validation_generator.flow_from_directory(batch_size=32,
                                                 directory='dataset_building/test',
                                                 shuffle=True,
                                                 target_size=(WIDTH, HEIGHT), 
                                                 class_mode='categorical')
# Out:
# Found 1500 images belonging to 6 classes.
# Found 300 images belonging to 6 classes.

# %%
train_dataset.class_indices
# Out:
# {'building_house': 0,
#  'mosque': 1,
#  'mud_house': 2,
#  'sky_building': 3,
#  'temple': 4,
#  'tinshed': 5}

# %%
validation_dataset.class_indices
# Out:
# {'building_house': 0,
#  'mosque': 1,
#  'mud_house': 2,
#  'sky_building': 3,
#  'temple': 4,
#  'tinshed': 5}

# %%
total_class=len(train_dataset.class_indices)
print('Number of classes in dataset: ',total_class)
# Out:
# Number of classes in dataset:  6

# %% [markdown]
# ## Plot some random image
# - class 0: building house
# - class 1: mosque
# - class 2: mud house
# - class 3: sky building
# - class 4: temple
# - class 5: tinshed

# %%
x,y=train_dataset.next()
fig=plt.figure(figsize=(15,15))
rows=5
cols=5
for i in range(rows*cols):
    fig.add_subplot(rows,cols,i+1)
    image=x[i]
    plt.imshow(image)
    plt.title(np.argmax(y[i]))
    plt.xticks([])
    plt.yticks([])
    
plt.show()

# %%
x,y=validation_dataset.next()
fig=plt.figure(figsize=(15,15))
rows=5
cols=5
for i in range(rows*cols):
    fig.add_subplot(rows,cols,i+1)
    image=x[i]
    plt.imshow(image)
    plt.title(np.argmax(y[i]))
    plt.xticks([])
    plt.yticks([])
    
plt.show()

# %% [markdown]
# ## Import VGG-16

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras import layers
import tensorflow as tf

# %%
base_model=VGG16(input_shape=(224,224,3),include_top=False)

# %%
base_model.trainable=False

# %%
total_class
# Out:
# 6

# %%
model = tf.keras.Sequential([
  base_model,
  layers.GlobalAvgPool2D(),
  #layers.Dense(1024,activation='relu'),
  layers.Dense(total_class,activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 3078
# =================================================================
# Total params: 14,717,766
# Trainable params: 3,078
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## Compile the model

# %%
model.compile( loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %% [markdown]
# ## Trained the model

# %%
epochs=30
batch_size=32
trainset_length=len(train_dataset.labels)
validation_length=len(validation_dataset.labels)
steps_per_epoch=(trainset_length//batch_size)
validation_steps=(validation_length//batch_size)
print(trainset_length)
print(validation_length)
print(steps_per_epoch)
print(validation_steps)
# Out:
# 1500
# 300
# 46
# 9

# %%
history = model.fit(train_dataset,
                    steps_per_epoch = steps_per_epoch,
                    epochs=epochs,
                    validation_data=validation_dataset,
                    validation_steps=validation_steps)
# Out:
# Epoch 1/30
# 46/46 [==============================] - 382s 8s/step - loss: 1.6863 - accuracy: 0.3985 - val_loss: 1.5389 - val_accuracy: 0.5590
# Epoch 2/30
# 46/46 [==============================] - 388s 8s/step - loss: 1.4343 - accuracy: 0.6621 - val_loss: 1.2889 - val_accuracy: 0.7014
# Epoch 3/30
# 46/46 [==============================] - 391s 8s/step - loss: 1.2150 - accuracy: 0.7541 - val_loss: 1.0875 - val_accuracy: 0.7188
# Epoch 4/30
# 46/46 [==============================] - 438s 10s/step - loss: 1.0508 - accuracy: 0.7697 - val_loss: 0.9438 - val_accuracy: 0.7569
# Epoch 5/30
# 46/46 [==============================] - 466s 10s/step - loss: 0.9281 - accuracy: 0.7881 - val_loss: 0.8425 - val_accuracy: 0.7778
# Epoch 6/30
# 46/46 [==============================] - 424s 9s/step - loss: 0.8348 - accuracy: 0.7943 - val_loss: 0.7817 - val_accuracy: 0.8021
# Epoch 7/30
# 46/46 [==============================] - 482s 10s/step - loss: 0.7657 - accuracy: 0.8079 - val_loss: 0.7252 - val_accuracy: 0.7535
# Epoch 8/30
# 46/46 [==============================] - 461s 10s/step - loss: 0.7084 - accuracy: 0.8188 - val_loss: 0.6602 - val_accuracy: 0.8090
# Epoch 9/30
# 46/46 [==============================] - 434s 9s/step - loss: 0.6654 - accuracy: 0.8038 - val_loss: 0.6284 - val_accuracy: 0.8229
# Epoch 10/30
# 46/46 [==============================] - 429s 9s/step - loss: 0.6363 - accuracy: 0.8174 - val_loss: 0.5963 - val_accuracy: 0.8194
# Epoch 11/30
# 46/46 [==============================] - 391s 9s/step - loss: 0.5934 - accuracy: 0.8386 - val_loss: 0.5849 - val_accuracy: 0.7951
# Epoch 12/30
# 46/46 [==============================] - 429s 9s/step - loss: 0.5773 - accuracy: 0.8331 - val_loss: 0.5526 - val_accuracy: 0.8333
# Epoch 13/30
# 46/46 [==============================] - 433s 9s/step - loss: 0.5513 - accuracy: 0.8426 - val_loss: 0.5401 - val_accuracy: 0.7986
# Epoch 14/30
# 46/46 [==============================] - 428s 9s/step - loss: 0.5339 - accuracy: 0.8535 - val_loss: 0.5220 - val_accuracy: 0.8194
# Epoch 15/30
# 46/46 [==============================] - 431s 9s/step - loss: 0.5186 - accuracy: 0.8345 - val_loss: 0.4974 - val_accuracy: 0.8299
# Epoch 16/30
# 46/46 [==============================] - 426s 9s/step - loss: 0.5042 - accuracy: 0.8420 - val_loss: 0.4932 - val_accuracy: 0.8368
# Epoch 17/30
# 46/46 [==============================] - 411s 9s/step - loss: 0.4820 - accuracy: 0.8563 - val_loss: 0.4770 - val_accuracy: 0.8160
# Epoch 18/30
# 46/46 [==============================] - 434s 9s/step - loss: 0.4757 - accuracy: 0.8542 - val_loss: 0.4642 - val_accuracy: 0.8403
# Epoch 19/30
# 46/46 [==============================] - 428s 9s/step - loss: 0.4668 - accuracy: 0.8569 - val_loss: 0.4547 - val_accuracy: 0.8368
# Epoch 20/30
# 46/46 [==============================] - 407s 9s/step - loss: 0.4567 - accuracy: 0.8658 - val_loss: 0.4455 - val_accuracy: 0.8438
# Epoch 21/30
# 46/46 [==============================] - 416s 9s/step - loss: 0.4397 - accuracy: 0.8658 - val_loss: 0.4438 - val_accuracy: 0.8438
# Epoch 22/30
# 46/46 [==============================] - 410s 9s/step - loss: 0.4367 - accuracy: 0.8665 - val_loss: 0.4474 - val_accuracy: 0.8299
# Epoch 23/30
# 46/46 [==============================] - 462s 10s/step - loss: 0.4176 - accuracy: 0.8699 - val_loss: 0.4268 - val_accuracy: 0.8507
# Epoch 24/30
# 46/46 [==============================] - 442s 10s/step - loss: 0.4225 - accuracy: 0.8678 - val_loss: 0.4275 - val_accuracy: 0.8576
# Epoch 25/30
# 46/46 [==============================] - 450s 10s/step - loss: 0.4119 - accuracy: 0.8760 - val_loss: 0.4172 - val_accuracy: 0.8611
# Epoch 26/30
# 46/46 [==============================] - 433s 9s/step - loss: 0.4010 - accuracy: 0.8706 - val_loss: 0.4029 - val_accuracy: 0.8507
# Epoch 27/30
# 46/46 [==============================] - 443s 10s/step - loss: 0.3960 - accuracy: 0.8781 - val_loss: 0.4196 - val_accuracy: 0.8368
# Epoch 28/30
# 46/46 [==============================] - 453s 10s/step - loss: 0.3931 - accuracy: 0.8808 - val_loss: 0.3990 - val_accuracy: 0.8403
# Epoch 29/30
# 46/46 [==============================] - 479s 10s/step - loss: 0.3946 - accuracy: 0.8781 - val_loss: 0.3835 - val_accuracy: 0.8542
# Epoch 30/30
# 46/46 [==============================] - 435s 9s/step - loss: 0.3722 - accuracy: 0.8842 - val_loss: 0.3883 - val_accuracy: 0.8472

# %% [markdown]
# ## Plot Accuracy and Loss Graph

# %%
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.title('Training accuracy graph')
plt.plot(history.history['accuracy'],label='accuracy')
plt.plot(history.history['val_accuracy'],label='val_accuracy')
plt.legend()
plt.show()

# %%
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Loss training graph')
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Softmax activation fuction
#
# three class labels will be integer encoded as 0, 1, and 2. Then encoded to vectors as follows:
#
# - Class 0: [1, 0, 0]
# - Class 1: [0, 1, 0]
# - Class 2: [0, 0, 1]
#
# The softmax output might look as follows, which puts the most weight on class 1 and less weight on the other classes.
#
# [0.09003057 0.66524096 0.24472847] -> [0,1,0]
#
# <b>equaltion</b> e^z/sum (e^z1,...,e^zn)

# %% [markdown]
# ## Adam optimzer

# %% [markdown]
# Adam optimization is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#
# According to Kingma et al., 2014, the method is "computationally efficient, has little memory requirement, invariant to diagonal rescaling of gradients, and is well suited for problems that are large in terms of data/parameters".

# %% [markdown]
# ## Testing data using test set

# %%
test_loss,test_accuracy=model.evaluate(validation_dataset)
print('Test Loss: ',test_loss)
print('Test Accuracy: ',test_accuracy)
# Out:
# 10/10 [==============================] - 61s 6s/step - loss: 0.3818 - accuracy: 0.8533
# Test Loss:  0.38180065155029297
# Test Accuracy:  0.8533333539962769

# %%
print('Accuracy of the model is : ',test_accuracy*100)
# Out:
# Accuracy of the model is :  85.33333539962769

# %% [markdown]
# ## Evaluate the model using test image
# - class 0: building house
# - class 1: mosque
# - class 2: temple
# - class 4: tinshed

# %%
from tensorflow.keras.preprocessing import image

# %%
random_image=image.load_img('tinshed19.png',target_size=(224,224))
plt.imshow(random_image)
random_image=image.img_to_array(random_image)
test_image=random_image.reshape((1,)+random_image.shape)
print(test_image.shape)
predicted_class=model.predict(test_image)
print(predicted_class)
print(np.argmax(predicted_class))
# Out:
# (1, 224, 224, 3)
# [[5.4112016e-33 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   5.2782349e-18]]
# 5

# %%
random_image=image.load_img('building0.png',target_size=(224,224))
plt.imshow(random_image)
random_image=image.img_to_array(random_image)
test_image=random_image.reshape((1,)+random_image.shape)
print(test_image.shape)
predicted_class=model.predict(test_image)
print(predicted_class)
print(np.argmax(predicted_class))
# Out:
# (1, 224, 224, 3)
# [[1.3714946e-05 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00]]
# 0

# %%
random_image=image.load_img('building1.png',target_size=(224,224))
plt.imshow(random_image)
random_image=image.img_to_array(random_image)
test_image=random_image.reshape((1,)+random_image.shape)
print(test_image.shape)
predicted_class=model.predict(test_image)
print(predicted_class)
print(np.argmax(predicted_class))
# Out:
# (1, 224, 224, 3)
# [[1.0000000e+00 1.3751913e-36 0.0000000e+00 0.0000000e+00 5.2817681e-30
#   0.0000000e+00]]
# 0

# %%
random_image=image.load_img('mosque35.png',target_size=(224,224))
plt.imshow(random_image)
random_image=image.img_to_array(random_image)
test_image=random_image.reshape((1,)+random_image.shape)
print(test_image.shape)
predicted_class=model.predict(test_image)
print(predicted_class)
print(np.argmax(predicted_class))
# Out:
# (1, 224, 224, 3)
# [[0. 1. 0. 0. 1. 0.]]
# 1

# %% [markdown]
# ## Save Model h5 format
# This file includes
# - Model architecture
# - Model weight values during training
# - model training config
# - optimizer

# %%
import time
t = time.time()
export_path_keras = "Saved Model/VGG16_model_{}_time_{}.h5".format(test_accuracy,int(t))
print(export_path_keras)
model.save(export_path_keras)
# Out:
# Saved Model/VGG16_model_0.8533333539962769_time_1617470615.h5

# %% [markdown]
# ## Reload the model h5 format

# %%
from tensorflow.keras.models import load_model

# %%
reload_model=load_model(export_path_keras)
reload_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 3078
# =================================================================
# Total params: 14,717,766
# Trainable params: 3,078
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## Experiment with reload model h5 format

# %%
print(len(reload_model.weights))
print(reload_model.output_shape)
# Out:
# 28
# (None, 6)

# %% [markdown]
# ## Export as SavedModel
#  SavedModel is a standalone serialization format for Tensorflow objects, supported by TensorFlow serving as well as TensorFlow implementations other than Python. A SavedModel contains a complete TensorFlow program, including weights and computation. It does not require the original model building code to run, which makes it useful for sharing or deploying (with TFLite, TensorFlow.js, TensorFlow Serving, or TFHub)
# - A TensorFlow checkpoint containing the model weights
# - Model architecture config

# %%
t = time.time()

export_path_sm = "Saved Model/TL VGG16_{}_model_{}".format(test_accuracy,int(t))
print(export_path_sm)

tf.saved_model.save(model, export_path_sm)

# %% [markdown]
# ## Load SavedModel

# %%
reload_tf_saved_model=tf.saved_model.load(export_path_sm)

# %%
reload_tf_saved_model.signatures['serving_default']

# %%
reload_tf_saved_model
